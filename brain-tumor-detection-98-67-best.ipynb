# %%
# !pip install torch torchvision opencv-python
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.10/site-packages (4.10.0.82)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from torchvision) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->torchvision) (2024.2.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)

# %%
# !pip install imutils torchsummary
# Out:
# Requirement already satisfied: imutils in /opt/conda/lib/python3.10/site-packages (0.5.4)
# Requirement already satisfied: torchsummary in /opt/conda/lib/python3.10/site-packages (1.5.1)

# %%
import numpy as np
import pandas as pd
import os
from os import listdir
import torch
import torchvision.transforms as transforms
from torchvision.utils import save_image
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms

# %%
image_dir = "../input/brain-tumor-detection/"

# %%
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import models
from sklearn.model_selection import train_test_split
import torch.nn.functional as F
import imutils

# %%
class CustomDataset(Dataset):
    def __init__(self, directory, transform=None, add_pixels_value=0):
        self.directory = directory
        self.transform = transform
        self.add_pixels_value = add_pixels_value
        self.image_paths = [os.path.join(directory, img_name) for img_name in os.listdir(directory)]
        self.labels = [self.get_label(os.path.join(directory, img_name)) for img_name in os.listdir(directory)]

    def get_label(self, img_name):
        label = 1 if 'yes' in img_name else 0
        return label

    def crop_image(self, img):
        
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        gray = cv2.GaussianBlur(gray, (5, 5), 0)
        
        thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
        thresh = cv2.erode(thresh, None, iterations=2)
        thresh = cv2.dilate(thresh, None, iterations=2)

        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = imutils.grab_contours(cnts)
        c = max(cnts, key=cv2.contourArea)

        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])

        # Add contour on the image
        img_cnt = cv2.drawContours(img.copy(), [c], -1, (0, 255, 255), 4)

        # Add extreme points
        img_pnt = cv2.circle(img_cnt.copy(), extLeft, 8, (0, 0, 255), -1)
        img_pnt = cv2.circle(img_pnt, extRight, 8, (0, 255, 0), -1)
        img_pnt = cv2.circle(img_pnt, extTop, 8, (255, 0, 0), -1)
        img_pnt = cv2.circle(img_pnt, extBot, 8, (255, 255, 0), -1)

        ADD_PIXELS = self.add_pixels_value

        ADD_PIXELS = self.add_pixels_value
        new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
        return new_img

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         image = self.crop_image(image)
        image = cv2.resize(image, dsize=IMG_SIZE, interpolation=cv2.INTER_CUBIC)
        label = self.labels[idx]
        if self.transform:
            image = self.transform(image)
        
        return image, label

# %%
IMG_SIZE  = (224, 224)

# %%
train_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.RandomRotation(15),
    transforms.RandomResizedCrop(IMG_SIZE, scale=(0.9, 1.0), ratio=(0.9, 1.1)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ColorJitter(brightness=(0.1, 1.5)),
    transforms.RandomAffine(degrees=0, shear=0.05),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

test_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
# train_data = []
# for root, dirs, files in os.walk(image_dir+"/Training"):
#     for dir_name in dirs:
#         train_data += CustomDataset(directory=os.path.join(root, dir_name), transform=test_transform)
        
# print(f"Number of images in 'training' dataset: {len(train_data)}")
# Out:
# Number of images in 'training' dataset: 0

# %%
# test_data = []
# for root, dirs, files in os.walk(image_dir+"/Testing"):
#     for dir_name in dirs:
#         test_data += CustomDataset(directory=os.path.join(root, dir_name), transform=test_transform)
        
# print(f"Number of images in 'Testing' dataset: {len(test_data)}")
# Out:
# Number of images in 'Testing' dataset: 0

# %%
# Load datasets
yes_dataset = CustomDataset(directory=image_dir+'/yes', transform=test_transform)
no_dataset = CustomDataset(directory=image_dir+'/no', transform=test_transform)

# %%
# Combine and split the datasets
dataset = yes_dataset + no_dataset
train_data, test_data = train_test_split(dataset, test_size=0.2, random_state=42)

# train_data, _ = train_test_split(train_data, test_size=0.95, random_state=42)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

# %%
print(f"Number of images in Training: {len(train_data)}")
print(f"Number of images in Testing: {len(test_data)}")
# Out:
# Number of images in Training: 2400
# Number of images in Testing: 600

# %%
import math

to_pil = transforms.ToPILImage()

def plot_samples(data_loader, n=50):
    """
    Creates a gridplot for desired number of images (n) from the specified set
    """
    # Determine the number of rows and columns for the grid
    cols = int(math.ceil(n ** 0.5))
    rows = int(math.ceil(n / cols))
    fig, axes = plt.subplots(rows, cols, figsize=(10, 10))
    axes = axes.flatten()
    
    for i, (img, label) in enumerate(data_loader):
        if i >= n:
            break
        pil_img = to_pil(img)  # Convert tensor to PIL image
        axes[i].imshow(pil_img)
        axes[i].set_title(f'Label: {label}')
        axes[i].axis('off')
    
    # Hide any unused subplots
    for j in range(i + 1, len(axes)):
        axes[j].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
# plot_samples(train_data, 30)

# %%
class BrainTumorCNN(nn.Module):
    def __init__(self):
        super(BrainTumorCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.fc1 = nn.Linear(64 * 56 * 56, 512)
        self.dropout1 = nn.Dropout(0.5)  
        self.fc2 = nn.Linear(512, 1)
    
    def forward(self, x):
        x = self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))
        x = x.view(-1, 64 * 56 * 56)
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)  
        x = self.fc2(x)
        return x

# %%
# class BrainTumorCNN(nn.Module):
#     def __init__(self):
#         super(BrainTumorCNN, self).__init__()
#         self.model = models.resnet18(pretrained=True)
#         self.model.fc = nn.Linear(self.model.fc.in_features, 1)

#     def forward(self, x):
#         x = self.model(x)
#         return x

# %%
from torchsummary import summary

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = BrainTumorCNN().to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
# Print the model summary
summary(model, input_size=(3, 224, 224), device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 224, 224]             896
#        BatchNorm2d-2         [-1, 32, 224, 224]              64
#          MaxPool2d-3         [-1, 32, 112, 112]               0
#             Conv2d-4         [-1, 64, 112, 112]          18,496
#        BatchNorm2d-5         [-1, 64, 112, 112]             128
#          MaxPool2d-6           [-1, 64, 56, 56]               0
#             Linear-7                  [-1, 512]     102,760,960
#            Dropout-8                  [-1, 512]               0
#             Linear-9                    [-1, 1]             513
# ================================================================
# Total params: 102,781,057
# Trainable params: 102,781,057
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 41.35
# Params size (MB): 392.08
# Estimated Total Size (MB): 434.00
# ----------------------------------------------------------------

# %%
# Training Loop
def train(model, train_loader, criterion, optimizer, num_epochs=35):
    best_accuracy = 0
   
    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0
        t_correct = 0
        t_total = 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device).unsqueeze(1).float() 
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            predicted = torch.sigmoid(outputs) >= 0.5
#             _, predicted = torch.max(outputs.data, 1)
            t_total += labels.size(0)
            t_correct += (predicted == labels).sum().item()
                
        epoch_training_accuracy = (100 * t_correct / t_total)
#         print(f'Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader)}, Training Accuracy: {epoch_training_accuracy:.2f}%')
        
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device).unsqueeze(1).float()  
                outputs = model(images)
                predicted = torch.sigmoid(outputs) >= 0.5
#                 _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                
        epoch_accuracy = (100 * correct / total)
        print(f'Epoch {epoch+1}/{num_epochs}, Loss: {running_loss/len(train_loader)}, Training Accuracy: {epoch_training_accuracy:.2f}%,Testing Accuracy: {epoch_accuracy:.2f}%')
        
#         print(f'Accuracy: {epoch_accuracy:.2f}%')
        
        if epoch_accuracy > best_accuracy:
            best_accuracy = epoch_accuracy
            torch.save({'epoch': epoch + 1, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict(),'loss': criterion}, './best_weight_cnn.pth')

# %%
# Train the model
train(model, train_loader, criterion, optimizer,50)
# Out:
# Epoch 1/50, Loss: 1.197609966993332, Training Accuracy: 75.79%,Testing Accuracy: 89.67%
# Epoch 2/50, Loss: 0.28801173001527786, Training Accuracy: 87.54%,Testing Accuracy: 93.17%
# Epoch 3/50, Loss: 0.16372750689586005, Training Accuracy: 93.38%,Testing Accuracy: 93.50%
# Epoch 4/50, Loss: 0.1299500813583533, Training Accuracy: 95.29%,Testing Accuracy: 96.50%
# Epoch 5/50, Loss: 0.08127607131997744, Training Accuracy: 97.29%,Testing Accuracy: 97.67%
# Epoch 6/50, Loss: 0.05883791825423638, Training Accuracy: 98.38%,Testing Accuracy: 96.67%
# Epoch 7/50, Loss: 0.03506838206822673, Training Accuracy: 99.17%,Testing Accuracy: 97.33%
# Epoch 8/50, Loss: 0.03477080502857765, Training Accuracy: 99.12%,Testing Accuracy: 97.83%
# Epoch 9/50, Loss: 0.025460479374354084, Training Accuracy: 99.38%,Testing Accuracy: 98.00%
# Epoch 10/50, Loss: 0.013187828799709677, Training Accuracy: 99.83%,Testing Accuracy: 97.83%
# Epoch 11/50, Loss: 0.010722082608068983, Training Accuracy: 99.92%,Testing Accuracy: 97.67%
# Epoch 12/50, Loss: 0.012693586366561552, Training Accuracy: 99.75%,Testing Accuracy: 97.83%
# Epoch 13/50, Loss: 0.007595527875237167, Training Accuracy: 99.92%,Testing Accuracy: 97.83%
# Epoch 14/50, Loss: 0.0062825934278468295, Training Accuracy: 99.92%,Testing Accuracy: 97.50%
# Epoch 15/50, Loss: 0.007539084663925072, Training Accuracy: 99.96%,Testing Accuracy: 98.00%
# Epoch 16/50, Loss: 0.004699680979829281, Training Accuracy: 99.96%,Testing Accuracy: 98.17%
# Epoch 17/50, Loss: 0.0033090155699755995, Training Accuracy: 100.00%,Testing Accuracy: 98.17%
# Epoch 18/50, Loss: 0.0025386815747090925, Training Accuracy: 100.00%,Testing Accuracy: 97.83%
# Epoch 19/50, Loss: 0.0019485909536403293, Training Accuracy: 100.00%,Testing Accuracy: 98.00%
# Epoch 20/50, Loss: 0.0016751829577454677, Training Accuracy: 100.00%,Testing Accuracy: 97.83%
# Epoch 21/50, Loss: 0.004139960780739784, Training Accuracy: 99.88%,Testing Accuracy: 97.00%
# Epoch 22/50, Loss: 0.3215010623199244, Training Accuracy: 91.04%,Testing Accuracy: 96.33%
# Epoch 23/50, Loss: 0.07868919317921003, Training Accuracy: 97.21%,Testing Accuracy: 96.83%
# Epoch 24/50, Loss: 0.04506043461772303, Training Accuracy: 98.96%,Testing Accuracy: 97.67%
# Epoch 25/50, Loss: 0.01880307477588455, Training Accuracy: 99.42%,Testing Accuracy: 98.00%
# Epoch 26/50, Loss: 0.01062873580182592, Training Accuracy: 99.83%,Testing Accuracy: 98.00%
# Epoch 27/50, Loss: 0.021198802792156735, Training Accuracy: 99.12%,Testing Accuracy: 98.33%
# Epoch 28/50, Loss: 0.006462366167688742, Training Accuracy: 99.92%,Testing Accuracy: 98.00%
# Epoch 29/50, Loss: 0.009593529001188775, Training Accuracy: 99.67%,Testing Accuracy: 98.33%
# Epoch 30/50, Loss: 0.0031788425046640136, Training Accuracy: 100.00%,Testing Accuracy: 98.33%
# Epoch 31/50, Loss: 0.003091284947731765, Training Accuracy: 99.96%,Testing Accuracy: 98.33%
# Epoch 32/50, Loss: 0.00213366015542609, Training Accuracy: 100.00%,Testing Accuracy: 98.33%
# Epoch 33/50, Loss: 0.010406795691427153, Training Accuracy: 99.50%,Testing Accuracy: 98.17%
# Epoch 34/50, Loss: 0.007803501113715659, Training Accuracy: 99.79%,Testing Accuracy: 98.67%
# Epoch 35/50, Loss: 0.004271905312586265, Training Accuracy: 99.92%,Testing Accuracy: 98.33%
# Epoch 36/50, Loss: 0.0047804252797019825, Training Accuracy: 99.88%,Testing Accuracy: 98.17%
# Epoch 37/50, Loss: 0.002211350574022314, Training Accuracy: 100.00%,Testing Accuracy: 98.50%
# Epoch 38/50, Loss: 0.0014615989321221908, Training Accuracy: 100.00%,Testing Accuracy: 98.50%
# Epoch 39/50, Loss: 0.0009877937420484765, Training Accuracy: 100.00%,Testing Accuracy: 98.50%
# Epoch 40/50, Loss: 0.0016950739006521569, Training Accuracy: 99.96%,Testing Accuracy: 98.67%
# Epoch 41/50, Loss: 0.0016176874258962927, Training Accuracy: 100.00%,Testing Accuracy: 98.33%
# Epoch 42/50, Loss: 0.0014864772156821951, Training Accuracy: 100.00%,Testing Accuracy: 98.00%
# Epoch 43/50, Loss: 0.0011209710509804912, Training Accuracy: 99.96%,Testing Accuracy: 98.00%
# Epoch 44/50, Loss: 0.0013678241733578033, Training Accuracy: 100.00%,Testing Accuracy: 98.33%
# Epoch 45/50, Loss: 0.0006745185814967651, Training Accuracy: 100.00%,Testing Accuracy: 98.50%
# Epoch 46/50, Loss: 0.012999235427123494, Training Accuracy: 99.67%,Testing Accuracy: 97.50%
# Epoch 47/50, Loss: 0.06785074513444367, Training Accuracy: 97.58%,Testing Accuracy: 97.67%
# Epoch 48/50, Loss: 0.04762693901003028, Training Accuracy: 98.58%,Testing Accuracy: 97.50%
# Epoch 49/50, Loss: 0.021733801489851125, Training Accuracy: 99.21%,Testing Accuracy: 96.50%
# Epoch 50/50, Loss: 0.01234066388492162, Training Accuracy: 99.54%,Testing Accuracy: 98.33%

# %%
model_best = BrainTumorCNN().to(device)

best_model_cp = torch.load('best_weight_cnn.pth')
best_model_epoch = best_model_cp['epoch']
print(f"Best model was saved at {best_model_epoch} epochs\n")
# Out:
# Best model was saved at 34 epochs

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Evaluation

def evaluate(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    tp,tn,fp,fn = 0,0,0,0
    total_confusion_matrix = None
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device).unsqueeze(1).float() 
            outputs = model(images)
            predicted = torch.sigmoid(outputs) >= 0.5
#             _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            batch_confusion_matrix = confusion_matrix(labels.cpu().numpy(), predicted.cpu().numpy(), labels=[0, 1])
#             batch_confusion_matrix = confusion_matrix(labels.cpu().numpy(), predicted.cpu().numpy())
            if total_confusion_matrix is None:
                total_confusion_matrix = batch_confusion_matrix
            else:
                total_confusion_matrix += batch_confusion_matrix
            etn, efp, efn, etp = batch_confusion_matrix.ravel()

            tp += etp
            tn += etn
            fp += efp
            fn += efn
    
    print(f"TP: {tp}, TN: {tn}, FP: {fp}, FN: {fn}")
    print(f'Accuracy: {(100 * correct / total):.2f}%, Total: {total}, Correct: {correct}, Wrong: {total-correct}')
    # Plot the confusion matrix
    plt.figure(figsize=(6, 4))
    sns.heatmap(total_confusion_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix")
    plt.show()

# %%
# Evaluate the model
model_best.load_state_dict(best_model_cp['model_state_dict'])

evaluate(model_best, test_loader)
# Out:
# TP: 308, TN: 284, FP: 3, FN: 5
# Accuracy: 98.67%, Total: 600, Correct: 592, Wrong: 8
